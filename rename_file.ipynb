# %%
# !python /content/drive/MyDrive/rename_files.py
# Out:
# Copy of child_level_cnn_glove.50d_4.txt
# child_level_cnn_glove.50d_4.txt
# Copy of child_level_cnn_glove.50d_1.txt
# child_level_cnn_glove.50d_1.txt
# Copy of child_level_cnn_FastText_1.txt
# child_level_cnn_FastText_1.txt
# Copy of child_level_cnn_FastText_2.txt
# child_level_cnn_FastText_2.txt
# Copy of child_level_cnn_FastText_3.txt
# child_level_cnn_FastText_3.txt
# Copy of child_level_cnn_glove.50d_3.txt
# child_level_cnn_glove.50d_3.txt
# Copy of child_level_cnn_FastText.keras
# child_level_cnn_FastText.keras
# Copy of child_level_cnn_glove.50d_2.txt
# child_level_cnn_glove.50d_2.txt
# Copy of child_level_cnn_FastText_4.txt
# child_level_cnn_FastText_4.txt
# Copy of child_level_cnn_glove.50d.keras
# child_level_cnn_glove.50d.keras
# Copy of child_level_cnn_glove.100d_1.txt
# child_level_cnn_glove.100d_1.txt
# Copy of child_level_cnn_glove.100d_2.txt
# child_level_cnn_glove.100d_2.txt
# Copy of child_level_cnn_glove.200d_4.txt
# child_level_cnn_glove.200d_4.txt
# ...
