# %% [markdown]
# #Download GloVe Pre-Trained

# %%
# import requests
# file_url="https://doc-0k-1s-docs.googleusercontent.com/docs/securesc/klilh452icfo6fnou748usvfbjbikbf2/g878vtuma0a4td9jcaqlfgbrdpbn2o12/1698790725000/06848720943842814915/13009194416623153479/0B7XkCwpI5KDYNlNUTTlSS21pQmM?e=download&ax=AI0foUrvtxXALb1d3XkRYFMGZsnqAvoLwyqp-c9wA7-DobY3dzEnD5sH3ssLZV53iJz4WvrnVaZT49x3RptxHJqYLlmRZEvFznHMY6JKWVqwkL8BMPdXZ4AH_UiT2k7UwSeCD0nn9pnPPLdrv7LRXro-YvnzzlFwr4cWViUaW95Cbr7ChvFzSQx0la5FJesHj5RhHesBOofQmjJFZTeGXSBctm06cx3YaMCbRhh27BLR6ZyLXUnfKJmwHWb9cYriSGE9DMyDSHLWtFwrB32VDIWaJmkGbc10Y_57tLOSJ-N1xeYVkRKnSRgYhSl2p-r4qkV9mIGCBMJ1ywBzPG56_eaqsnO9gSKb8lG96P7BV_yTHJr7rzubeGLVTNUKUMqgnP-tWHibjiMd5edJzwvxucGlNRhS-s27bBIxmkAaGkyPsKyy9ERNWoXaoLc9GVHb7WdVJJpgJV5DO40-0yKlFo5IQPbkcuwa9K3kTmPqaoZGutNjT_CcF6xOm5G_7OwDLycLlFuvlFic8nF5JtJ3-zjUuOnql0mDKX_wA-av8cX5YTKc9QGajbgqs1KTlHxgortdvJFbdAoxbSvpIHprTxSatLYN2PPAT8-NlRfs-GSslGLqfQvMgxm6aNxPR0QwCSa9ZXSCAUAa69iL9Vo-0jr662PpCPgryMyRNftwZIB_Bc02IbPC43Qc01_WNMvlEPEXW9AvZIEM-GFY25RU3LjRIguFXeBnwnT1elEqAFKm8hh6vOAHTFUO2kGq0-t5_PQ_ioedHOpG4WkGvLozgS9yLAZ34AX_LB5Ak4k27S2iNXKeust_ygTjElGf5ZBTCKpBPZzQz7tSSSgRve3KjmnTSDf58asF7nxw2G9ybix4fXk5Rvs8epBTi3_TWyiKOdTY3YwchVkzrbGjX9WNRzilMOn5Trci&uuid=e1d3cb75-ebdb-4e25-925c-a1035034e4f6&authuser=0"

# r = requests.get(file_url, stream = True)

# with open("/content/drive/MyDrive/GoogleNews-vectors-negative300.bin.gz", "wb") as file:
#     for block in r.iter_content(chunk_size = 1024):
#          if block:
#              file.write(block)

# %%
# !unzip "/content/drive/MyDrive/glove.6B.zip"

# %%
# !unzip "/content/drive/MyDrive/fasttext.zip"

# %% [markdown]
# #Function and Models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/child-level-data.py
# Out:
#                                             Abstract  ...    Y
# 0  (2 + 1)-dimensional non-linear optical waves t...  ...   12
# 1  (beta-amyloid (A beta) and tau pathology becom...  ...   74
# 2  (D)ecreasing of energy consumption and environ...  ...   68
# 3  (Hybrid) electric vehicles are assumed to play...  ...   26
# 4  (L)-3,4-Dihydroxyphenylalanine ((L)-DOPA) rema...  ...  115
#
# [5 rows x 7 columns]
# CS
# Medical
# Civil
# ECE
# biochemistry
# MAE
# Psychology

# %%
import numpy as np
import pandas as pd
import string
import os

number=3
areas=["CS","Civil","ECE","MAE","Medical","Psychology","biochemistry"]

#Make Directory For Child-Level
if os.path.exists(f'/content/drive/MyDrive/{areas[number]}') == False:
  os.mkdir(f'/content/drive/MyDrive/{areas[number]}')


data=pd.read_csv(f"/content/{areas[number]}.csv")
data.head() #show the head of the dataset
# Out:
#    index                                           Abstract  \
# 0      8  (We develop a generalised unsteady plume theor...
# 1     43  1. Leaf economics and hydraulic traits strongl...
# 2     56  1. Vulnerability segmentation hypothesis propo...
# 3     75  2D cell culture and preclinical animal models ...
# 4     89  3D-PTV is a quantitative flow measurement tech...
#
#                      Domain
# 0         Fluid mechanics
# 1              Hydraulics
# 2              Hydraulics
# 3   computer-aided design
# 4         Fluid mechanics

# %%
pip install keras-tuner --upgrade
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.10/dist-packages (1.4.6)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)

# %%
#SKLEARN LINRARIES
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split,KFold

#NLTK LIBRARIES
import nltk
from nltk.tokenize import sent_tokenize,word_tokenize,RegexpTokenizer
nltk.download('stopwords')
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
stop_words=stopwords.words("english")
from nltk.stem import PorterStemmer

from bs4 import BeautifulSoup
from IPython.display import clear_output
import numpy as np
import pandas as pd
import string
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from collections import Counter

#Tokenizing
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

def Progress(string):
    global iterator
    global number_of_records
    percent=((iterator/number_of_records)*10)

    if percent%5==0:
        clear_output(wait=True)
        print(string+":"+str(percent)+"%")

    iterator=iterator+1

def remove_strip(text):
    return text.strip()

def remove_noise(text):


    soup=BeautifulSoup(text,"html.parser")
    text=soup.get_text()
    return text

def remove_punc(text):


    rem_punc=RegexpTokenizer(r'\w+')
    return ' '.join(rem_punc.tokenize(text))

def remove_stopwords(text):


    words=word_tokenize(text)
    return ' '.join([w.lower() for w in words if not w.lower() in stop_words])

def stemming(text):


    words=word_tokenize(text)
    porter=PorterStemmer()
    return ' '.join([porter.stem(w) for w in words ])



def Vocab(text):
  global freqdist
  words=word_tokenize(text)
  vocab.update(nltk.FreqDist(words).keys())

def build_vocab(documents):

  #maing vocab
  documents.apply(Vocab)

  return vocab
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# define the model
import keras
from keras.models import Sequential
from keras.models import Model
import numpy as np
from keras.layers import Dense, Input, Flatten
from keras.layers import Conv1D, MaxPooling1D, Embedding, Dropout, LSTM, GRU, Bidirectional,SimpleRNN
from keras.optimizers import Adam,RMSprop
import keras_tuner as kt
import tensorflow as tf
from keras.metrics import Accuracy,Precision,Recall,F1Score

# define the model
class CNN(kt.HyperModel):
  def __init__(self,wv,complexity,max_length,nClasses):
    self.wv=wv
    self.complexity=complexity
    self.max_length=max_length
    self.nClasses=nClasses

  def build(self,hp):
    model=Sequential()
    model.add(Embedding(input_dim=(self.wv.shape[0]),
                            output_dim=(self.wv.shape[1]),
                            weights=[self.wv],
                            input_length=self.max_length,
                            trainable=False))
    if self.complexity==0:

      for j in range(0,hp.Int("Testing number of Conv and maxpolling layer", min_value=1, max_value=1, step=1)):
        model.add(Conv1D(256,hp.Choice("Testing the kernel size of conv",[3,5]), activation='relu'))
        model.add(MaxPooling1D(5))

        model.add(Flatten())
      for j in range(0,hp.Int("Testing number of Desnse Layer", min_value=1, max_value=1, step=1)):
        model.add(Dense(hp.Int("Testing number of nuerons Desnse Layer", min_value=32, max_value=256, step=32), activation='relu'))
        model.add(Dense(self.nClasses, activation='softmax'))

        # for j in range(0,2):
        #   model.add(Conv1D(256,3, activation='relu'))
        #   model.add(MaxPooling1D(3))

        # model.add(Flatten())
        # for j in range(0,3):
        #   model.add(Dense(100))
        # model.add(Dense(self.nClasses, activation='softmax'))
    else:

        filter_sizes = [3, 4, 5, 6, 7]
        for fsz in filter_sizes:
            model.add(Conv1D(128,fsz,activation='relu'))
            model.add(MaxPooling1D(5))

        model.add(Conv1D(128,5, activation='relu'))
        model.add(MaxPooling1D(5))
        model.add(Conv1D(128,5, activation='relu'))
        model.add(MaxPooling1D(30))

        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
        model.add(Dense(self.nClasses, activation='softmax'))

    model.compile(optimizer=RMSprop(learning_rate=0.001),loss=["categorical_crossentropy"],metrics=["accuracy",Precision(name="precision"),Recall(name="recall")])
    return model

class RNN():
  def __init__(self,wv,complexity,max_length,nClasses):
    self.wv=wv
    self.complexity=complexity
    self.max_length=max_length
    self.nClasses=nClasses

  def build(self):
    model = Sequential()
    model.add(Embedding(input_dim=(self.wv.shape[0]),
                        output_dim=(self.wv.shape[1]),
                        weights=[self.wv],
                        input_length=self.max_length,
                        trainable=False))

    model.add(GRU(100))
    model.add(Dense(self.nClasses, activation='softmax'))
    model.compile(optimizer=RMSprop(learning_rate=0.001),loss=["categorical_crossentropy"],metrics=["accuracy",Precision(name="precision"),Recall(name="recall")])
    return model



class DNN(kt.HyperModel):
  def __init__(self,Shape,nClasses,nLayers=3,Number_Node=100, dropout=0.5):
    self.Shape=Shape
    self.nLayers=nLayers
    self.Number_Node=Number_Node
    self.nClasses=nClasses
    self.dropout=dropout

  def build(self,hp):
    model = Sequential()
    model.add(Dense(hp.Int("Testing number of nuerons Desnse Layer", min_value=100, max_value=400, step=100), input_shape=(self.Shape,)))
    model.add(Dropout(self.dropout))

    for i in range(0,hp.Int("Testing number of Desnse Layer", min_value=1, max_value=3, step=1)):
        model.add(Dense(hp.Int("Testing number of nuerons Desnse Layer", min_value=100, max_value=400, step=100), activation='relu'))
        model.add(Dropout(self.dropout))

    model.add(Dense(self.nClasses, activation='softmax'))
    model.compile(loss='categorical_crossentropy',metrics=["accuracy",Precision(name="precision"),Recall(name="recall")],optimizer='adam')
    return model
    return model

# %%
data.tail() #show the end of the dataset
# Out:
#       index                                           Abstract  \
# 3292  46920  Xylem embolism is one of the main processes in...
# 3293  46921  Xylem resistance to cavitation is an important...
# 3294  46930  Yield stress fluid flows occur in a great many...
# 3295  46958  Zeolites are fascinating and versatile materia...
# 3296  46963  Zero-wear is considered as wear within the lim...
#
#                              Domain
# 3292                   Hydraulics
# 3293                   Hydraulics
# 3294              Fluid mechanics
# 3295               Thermodynamics
# 3296   Internal combustion engine

# %%
data.columns
# Out:
# Index(['index', 'Abstract', 'Domain'], dtype='object')

# %%
data.shape
# Out:
# (3297, 3)

# %%
data.describe()
# Out:
#               index
# count   3297.000000
# mean   26301.029421
# std    13727.619252
# min        8.000000
# 25%    15189.000000
# 50%    28665.000000
# 75%    38527.000000
# max    46963.000000

# %%
data.isnull().any() #checking the dataset have null values
# Out:
# index       False
# Abstract    False
# Domain      False
# dtype: bool

# %%
data.isnull().sum() #checking number of null values
# Out:
# index       0
# Abstract    0
# Domain      0
# dtype: int64

# %%
data['Domain'].value_counts() # check the vlaues for each columns
# Out:
#  Machine design                  420
#  Hydraulics                      402
#  Internal combustion engine      387
#  Fluid mechanics                 386
#  computer-aided design           371
#  Thermodynamics                  361
#  Manufacturing engineering       346
#  Strength of materials           335
#  Materials Engineering           289
# Name: Domain, dtype: int64

# %%
# data=data.loc[:,["Abstract","Domain"]]
# data

# %% [markdown]
# #Preprocessing

# %%
#before preprocessing
print("------------------------------------------------")
print(data["Abstract"][13])
print("------------------------------------------------")



#removing noise
iterator=1
data['Abstract']=data['Abstract'].apply(remove_noise)

#removeing puctuation
iterator=1
data['Abstract']=data['Abstract'].apply(remove_punc)

#removeing stopwords
iterator=1
data['Abstract']=data['Abstract'].apply(remove_stopwords)

#stemming
#     iterator=1
#     area_data['Abstract']=data['Abstract'].apply(stemming)


#after preprocessing
print("------------------------------------------------")
print(data["Abstract"][13])
print("------------------------------------------------")
# Out:
# ------------------------------------------------
# A bottom-up, multiscale modeling approach is presented to carry out high-fidelity virtual mechanical tests of composite materials and structures. The strategy begins with the in situ measurement of the matrix and interface mechanical properties at the nanometer-micrometer range to build up a ladder of the numerical simulations, which take into account the relevant deformation and failure mechanisms at different length scales relevant to individual plies, laminates and components. The main features of each simulation step and the information transferred between length scales are described in detail as well as the current limitations and the areas for further development. Finally, the roadmap for the extension of the current strategy to include functional properties and processing into the simulation scheme is delineated.
# ------------------------------------------------
# ------------------------------------------------
# bottom multiscale modeling approach presented carry high fidelity virtual mechanical tests composite materials structures strategy begins situ measurement matrix interface mechanical properties nanometer micrometer range build ladder numerical simulations take account relevant deformation failure mechanisms different length scales relevant individual plies laminates components main features simulation step information transferred length scales described detail well current limitations areas development finally roadmap extension current strategy include functional properties processing simulation scheme delineated
# ------------------------------------------------

# %% [markdown]
# #Tokenizer

# %%
# #number of distince frequency
# print('--------------------------------------------------------------------------------------------------------')
# vocab=Counter()
# freqdist=len(build_vocab(data["Abstract"]))
# print("Number Frequency "+str(freqdist))
# print('--------------------------------------------------------------------------------------------------------')


# # Tokenize our training data
# print('--------------------------------------------------------------------------------------------------------')
# print("Tokenizing...")
# tokenizer = Tokenizer(freqdist-200)
# tokenizer.fit_on_texts(data['Abstract'])
# # Encode training data sentences into sequences
# sequences = tokenizer.texts_to_sequences(data['Abstract'],)

# # Get our training data word index
# word_to_index = tokenizer.word_index

# # Get max training sequence length
# maxlen = max([len(x) for x in sequences])

# #Pad the training sequences
# sequences_padded = pad_sequences(sequences,maxlen=694)

# # Output the results of our work
# print("Word index:\n",len(word_to_index))
# print("\nSequences:", sequences[0])
# print("\nSequences Length:", len(sequences[0]))
# print("\nPadded Sequences:", sequences_padded[0])
# print("\nPadded Sequences Length:", len(sequences_padded[0]))
# print('--------------------------------------------------------------------------------------------------------')

# %%
sequences_padded=np.loadtxt('/content/drive/MyDrive/sequences_padded.txt',dtype='int32')

# %% [markdown]
# #Word_Embedding

# %%
# from gensim.scripts.glove2word2vec import glove2word2vec

# input_files=['glove.6B.50d.txt','glove.6B.100d.txt','glove.6B.200d.txt','glove.6B.300d.txt']
# output_files=['glove.50d.txt','glove.100d.txt','glove.200d.txt','glove.300d.txt']
# for index in range(0,len(input_files)):
#   glove2word2vec(input_files[index],output_files[index])

# %%
# from gensim.models import KeyedVectors

# words_embeddings={}

# #GloVe 50d
# words_embeddings["glove.50d"]=KeyedVectors.load_word2vec_format("/content/drive/MyDrive/glove.50d.txt",binary=False)
# # GloVe 100d
# words_embeddings["glove.100d"]=KeyedVectors.load_word2vec_format("/content/drive/MyDrive/glove.100d.txt",binary=False)
# #GloVe 200d
# words_embeddings["glove.200d"]=KeyedVectors.load_word2vec_format("/content/drive/MyDrive/glove.200d.txt",binary=False)
# #GloVe 300d
# words_embeddings["glove.300d"]=KeyedVectors.load_word2vec_format("/content/drive/MyDrive/glove.300d.txt",binary=False)
# #GoogleNews-vectors
# words_embeddings["GoogleNews-vectors"]=KeyedVectors.load_word2vec_format("/content/drive/MyDrive/GoogleNews-vectors-negative300.bin",binary=True)

# %%
# words_embeddings_matrix={}
# for key,wv in words_embeddings.items():
#   vocab=len(word_to_index)
#   vocab_word_embedding=wv.key_to_index.keys()

#   emb_matrix=np.zeros((vocab,len(wv.get_vector("computer"))))
#   # emb_matrix=np.random.random((vocab,len(wv.get_vector("computer"))))
#   emb_dict={}
#   not_existing_words=[]

#   for word,index in word_to_index.items():
#     if word in vocab_word_embedding:
#       if index==len(word_to_index.keys()):
#         continue
#       emb_dict[word]=wv.get_vector(word)
#       emb_matrix[index, :]=wv.get_vector(word)
#     else:
#       not_existing_words.append(word)

#   words_embeddings_matrix[key]=emb_matrix
#   print("Not Existing Word:",not_existing_words[1])
#   print("\n\nNumber Of Not Existing Word:",len(not_existing_words))
#   print("\n\nVector Of Existing Word good:",emb_dict["good"])
#   print("\n\nEmbeding Matrix shape",emb_matrix.shape)



#   del not_existing_words
#   del emb_dict
#   del emb_matrix

# %%
# words_embeddings["FastText"]=np.loadtxt("/content/drive/MyDrive/fasttext.txt")

# %%
words_embeddings_matrix={}
# keys=['glove.50d', 'glove.100d', 'glove.200d', 'glove.300d', 'GoogleNews-vectors', 'FastText']
keys=['glove.300d']
for key in keys:
  words_embeddings_matrix[key]=np.loadtxt(f'/content/drive/MyDrive/words_embeddings_matrix/{key}_matrix.txt')

# %% [markdown]
# # Document_Embedding

# %%
from gensim.models.doc2vec import TaggedDocument
tag_number=-1
def Tagging(text):
  global tag_number
  tag_number=tag_number+1
  return TaggedDocument(text,[tag_number])

# %%
from gensim.models.doc2vec import Doc2Vec
from gensim.utils import simple_preprocess
import os
vector_sizes=[50,100,200,300]
documents_embeddings={}


# if not os.path.isfile(f"/content/drive/MyDrive/Doc2Vec/CS_Doc2Vec50.model"):
#   data["Abstract"]=data["Abstract"].apply(simple_preprocess)
#   data["Abstract"]=data["Abstract"].apply(Tagging)
#   for vector_size in vector_sizes:
#     model=Doc2Vec(vector_size=vector_size,epochs=10,dm=1,min_count=2,pretrained_emb="/content/drive/MyDrive/glove.100d.txt")
#     model.build_vocab(data["Abstract"])
#     model.train(data["Abstract"],total_examples=len(data["Abstract"]),epochs=model.epochs)
#     print(model.docvecs.vectors.shape)
#     model.save(f"/content/drive/MyDrive/Doc2Vec/CS_Doc2Vec{vector_size}.model")

# %%
# documents_embeddings["doc2vec50"]=Doc2Vec.load("/content/drive/MyDrive/Doc2Vec/Data_doc2vec50.model")
# print(documents_embeddings["doc2vec50"].docvecs.vectors.shape)
# documents_embeddings["doc2vec100"]=Doc2Vec.load("/content/drive/MyDrive/Doc2Vec/Data_doc2vec100.model")
# print(documents_embeddings["doc2vec100"].docvecs.vectors.shape)
# documents_embeddings["doc2vec200"]=Doc2Vec.load("/content/drive/MyDrive/Doc2Vec/Data_doc2vec200.model")
# print(documents_embeddings["doc2vec200"].docvecs.vectors.shape)
documents_embeddings["doc2vec300"]=Doc2Vec.load("/content/drive/MyDrive/Doc2Vec/Data_doc2vec300.model")
print(documents_embeddings["doc2vec300"].docvecs.vectors.shape)
# Out:
# (46985, 300)
# <ipython-input-23-2e4a02a92453>:8: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   print(documents_embeddings["doc2vec300"].docvecs.vectors.shape)

# %%
# for key,wv in words_embeddings.items():
#   document_embedding=[]
#   for text in data["Abstract"].to_numpy():
#     words=word_tokenize(text)
#     vocab_word_embedding=wv.key_to_index.keys()
#     document_embedding.append(np.mean([wv.get_vector(word) for word in words if word in vocab_word_embedding],axis=0))
#   documents_embeddings["Doc2Vec"+key]=document_embedding

# %%
# del words_embeddings

# %%
# documents_embeddings={}
# keys=['GoogleNews-vectors']
# for key in keys:
#   documents_embeddings["Doc2Vec"+key]=np.loadtxt(f'/content/drive/MyDrive/documents_embeddings/{"Doc2Vec"+key}.txt')

# %% [markdown]
# #Model

# %%
from sklearn.preprocessing import LabelBinarizer

label=LabelBinarizer()
data_multi_class=label.fit_transform(data["Domain"])
print(data_multi_class.shape)
# Out:
# (3297, 9)

# %%
# temp=[]
# for index in data["index"]:
#   temp.append(sequences_padded[index])
# sequences_padded=np.array(temp)
# sequences_padded.shape

# %%
Excel_Output=pd.DataFrame(columns=["Classifier","Embedding","Dimension_Size"])

# %% [markdown]
# #CNN MODEL

# %%
from sklearn.model_selection import KFold


for key,wv in words_embeddings_matrix.items():
  best_model=None
  best_accuracy=0
  overwrite=True
  #Using KFOLD
  kfold=KFold(n_splits=4,shuffle=True)
  fold=1
  for train,test in kfold.split(sequences_padded,data_multi_class):
    #KFOLD
    #------------------------------------------------------------------------------------------
    x_train=sequences_padded[train]
    x_test=sequences_padded[test]
    y_train=data_multi_class[train]
    y_test=data_multi_class[test]
    #------------------------------------------------------------------------------------------


    #MODEL
    #------------------------------------------------------------------------------------------
    cnn=CNN(wv,0,max_length=len(x_train[0]),nClasses=y_train.shape[1])
    tunner=kt.Hyperband(hypermodel=cnn,objective="val_accuracy",overwrite=overwrite,max_epochs=4)
    tunner.search_space_summary()
    tunner.search(x_train, y_train, epochs=4,validation_data=(x_test,y_test),callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=3)])
    best_hps = tunner.get_best_hyperparameters(num_trials=1)[0]
    model = tunner.hypermodel.build(best_hps)
    history=model.fit(x_train, y_train, epochs=20,validation_data=(x_test,y_test),callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=3)])
    overwrite=False
    #------------------------------------------------------------------------------------------


    #PLOTING
    #------------------------------------------------------------------------------------------
    epochs_number=len(history.history["accuracy"])+1
    fig,axis=plt.subplots(2,2)
    axis[0][0].plot(range(1,epochs_number),history.history["accuracy"],label="Accuracy Train")
    axis[0][1].plot(range(1,epochs_number),history.history["loss"],label="Lost Train")
    axis[1][0].plot(range(1,epochs_number),history.history["val_accuracy"],label="Accuracy Test")
    axis[1][1].plot(range(1,epochs_number),history.history["val_loss"],label="Loss Test")
    axis[0][0].grid()
    axis[0][1].grid()
    axis[1][0].grid()
    axis[1][1].grid()
    axis[0][0].legend()
    axis[0][1].legend()
    axis[1][0].legend()
    axis[1][1].legend()
    plt.show()
    fig.savefig(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_CNN_plot_{key}_{fold}.jpg")
    #------------------------------------------------------------------------------------------


    #Saving Model and Accuracy and Loss
    #------------------------------------------------------------------------------------------
    accuracy_text=' '.join([str(number)for number in history.history["accuracy"]])
    loss_text=','.join([str(number)for number in history.history["loss"]])
    val_accuracy_text=' '.join([str(number)for number in history.history["val_accuracy"]])
    val_loss_text=' '.join([str(number)for number in history.history["val_loss"]])
    with open(f"/content/drive/MyDrive/{areas[number]}/child_level_cnn_{key}_{fold}.txt","w") as f:
      f.write("Accuracy Train:"+accuracy_text+"\n")
      f.write("Loss Train:"+loss_text+"\n")
      f.write("Accuracy Test:"+val_accuracy_text+"\n")
      f.write("Loss Test:"+val_loss_text+"\n")
    index=history.history["accuracy"].index(max(history.history["accuracy"]))
    Excel_Output=pd.concat([Excel_Output,pd.DataFrame([{"Classifier":"CNN","Embedding":key,"Dimension_Size":wv.shape[1],"Train Accuracy":history.history["accuracy"][index],"Train Precision":history.history["precision"][index]," Train Recall":history.history["recall"][index],"Test Accuracy":history.history["val_accuracy"][index],"Test Precision":history.history["val_precision"][index]," Test Recall":history.history["val_recall"][index]}])])
    #------------------------------------------------------------------------------------------

    #Find The Best Model
    #-----------------------------------------------------------------------------------------
    if(history.history["val_accuracy"][index]>best_accuracy):
      best_accuracy=history.history["val_accuracy"][index]
      best_model=model
    #-----------------------------------------------------------------------------------------
    fold=fold+1

  #Saving The Model
  #-----------------------------------------------------------------------------------------
  best_model.save(f"/content/drive/MyDrive/{areas[number]}/child_level_cnn_{key}.keras")
  #-----------------------------------------------------------------------------------------
Excel_Output.to_csv(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_CNN_OUTPU.csv")

# %% [markdown]
# #DNN MODEL

# %%
Excel_Output=pd.DataFrame(columns=["Classifier","Embedding","Dimension_Size"])
x_train,x_test,y_train,y_test=train_test_split(data["Abstract"],data_multi_class,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

#Building Vocabulary
#------------------------------------------
def build_dnnvocab(x_train):
  vocab=Counter()
  for abstract in x_train:
    words=word_tokenize(abstract)
    vocab.update(words)
  return vocab

vocab_train=build_dnnvocab(x_train)
print(vocab_train)
max_features=len([value for value in vocab_train.values() if value>1])
print("max_features",max_features)
#------------------------------------------
# Out:
# (11700,)
# (2925,)
# (11700, 56)
# (2925, 56)
# Counter({'patients': 17555, '0': 16150, '1': 13167, 'study': 10448, '2': 9479, 'p': 8706, 'results': 7653, 'treatment': 7086, '3': 6939, 'health': 6205, 'disease': 6119, 'associated': 6102, 'risk': 5873, '5': 5417, '4': 5081, 'group': 4807, 'methods': 4706, '6': 4692, 'may': 4639, 'c': 4575, 'using': 4563, 'clinical': 4551, 'data': 4398, 'age': 4360, 'years': 4249, 'levels': 4186, 'use': 4179, 'studies': 4178, 'women': 4144, 'compared': 3949, 'children': 3865, 'used': 3835, 'significantly': 3769, '95': 3757, 'also': 3749, 'significant': 3747, 'increased': 3710, 'high': 3699, 'analysis': 3664, 'among': 3578, 'care': 3480, 'higher': 3400, 'effects': 3390, 'related': 3368, '7': 3358, 'n': 3256, 'factors': 3242, 'based': 3218, '8': 3205, 'ci': 3120, 'control': 3091, 'cells': 3058, 'symptoms': 2930, 'however': 2920, '9': 2837, '10': 2833, 'time': 2828, 'low': 2765, 'two': 2758, 'one': 2751, 'reported': 2687, 'well': 2675, 'patient': 2674, 'background': 2579, 'groups': 2579, 'conclusions': 2568, 'effect': 2565, 'showed': 2546, 'activity': 2544, 'total': 2490, 'non': 2488, 'therapy': 2485, 'found': 2473, 'participants': 2374, 'including': 2357, 'stress': 2355, '12': 2348, 'lower': 2337, 'cell': 2309, 'expression': 2259, 'included': 2209, 'cancer': 2176, 'research': 2162, 'level': 2143, 'conclusion': 2133, 'findings': 2123, 'mean': 2115, 'review': 2096, 'population': 2092, 'evidence': 2089, 'elsevier': 2086, 'role': 2054, 'quality': 2039, 'association': 2010, 'life': 2009, 'different': 1995, 'potential': 1994, 'model': 1986, 'outcomes': 1978, 'development': 1964, 'diagnosis': 1948, 'b': 1947, 'chronic': 1943, 'hiv': 1914, 'induced': 1906, 'skin': 1902, 'first': 1896, 'rights': 1895, 'respectively': 1893, 'positive': 1886, 'changes': 1884, 'pain': 1871, 'bone': 1867, 'specific': 1866, 'function': 1863, '001': 1857, 'reserved': 1850, 'objective': 1849, 'year': 1848, 'diseases': 1841, 'new': 1831, 'three': 1825, 'months': 1823, 'response': 1812, 'identified': 1808, 'intervention': 1790, 'without': 1785, 'present': 1775, 'performed': 1760, 'observed': 1757, 'common': 1747, 'cases': 1728, 'management': 1726, 'sleep': 1710, 'type': 1701, 'rate': 1701, 'important': 1694, 'vs': 1684, 'self': 1667, 'primary': 1651, 'assessed': 1636, 'increase': 1623, 'number': 1595, 'social': 1593, 'could': 1591, 'early': 1586, 'protein': 1584, 'prevalence': 1582, 'aim': 1579, 'injury': 1577, 'men': 1576, 'factor': 1573, 'differences': 1568, 'beta': 1566, 'disorders': 1556, 'test': 1552, 'system': 1552, 'healthy': 1544, 'treated': 1543, 'injuries': 1506, 'serum': 1505, 'cognitive': 1502, 'anti': 1495, 'controls': 1493, 'follow': 1491, 'current': 1479, 'inflammatory': 1476, 'weight': 1470, 'score': 1464, 'il': 1453, 'effective': 1452, 'infection': 1449, 'medical': 1447, '20': 1446, 'within': 1440, 'individuals': 1439, 'g': 1439, 'blood': 1434, '05': 1434, 'efficacy': 1431, 'subjects': 1426, 'impact': 1424, 'drug': 1422, '18': 1411, 'conducted': 1404, 'testosterone': 1395, 'brain': 1394, 'decreased': 1393, 'support': 1391, 'physical': 1389, '2016': 1376, 'human': 1372, 'whether': 1370, 'baseline': 1361, 'mice': 1356, 'disorder': 1342, 'status': 1341, 'evaluated': 1337, '15': 1336, 'smoking': 1323, 'body': 1320, '30': 1319, 'reduced': 1316, 'rates': 1315, 'method': 1308, 'alpha': 1300, '2017': 1295, 'ad': 1294, '11': 1291, 'information': 1290, 'suggest': 1287, 'loss': 1274, 'although': 1266, 'long': 1264, 'e': 1262, 'r': 1257, 'days': 1252, 'scores': 1251, 'exposure': 1251, 'regression': 1247, 'mg': 1238, 'l': 1238, 'period': 1233, 'negative': 1229, '24': 1229, 'multiple': 1229, 'case': 1218, 'due': 1213, 'outcome': 1211, '13': 1210, '25': 1208, 'term': 1201, 'index': 1199, '50': 1199, 'mortality': 1197, 'measured': 1195, 'relationship': 1195, 'conditions': 1185, 'assess': 1184, 'evaluate': 1182, 'determine': 1180, 'models': 1179, 'ratio': 1174, 'interventions': 1173, '14': 1171, 'depression': 1168, 'functional': 1165, 'less': 1159, 'measures': 1153, 'day': 1148, ...
# max_features 35347

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
import joblib

# Bag of Words
#------------------------------------------
cv=CountVectorizer(binary=False,ngram_range=(1,3),max_features=max_features)
cv_train=cv.fit_transform(x_train)
print(len(cv.vocabulary_))

# example for saving python object as pkl
joblib.dump(cv.vocabulary_, f"/content/drive/MyDrive/{areas[number]}/vectorizer.pkl")

cv_test=cv.transform(x_test)

cv_train.sort_indices()
cv_test.sort_indices()

print(cv_train.shape)
print(cv_test.shape)
#------------------------------------------

# # TF-IDF
# #------------------------------------------
# tf=TfidfVectorizer(min_df=0,max_df=1,binary=False,ngram_range=(1,3),max_features=max_features)
# tf_train=tf.fit_transform(x_train)
# tf_test=tf.transform(x_test)

# tf_train.sort_indices()
# tf_test.sort_indices()

# print(tf_train.shape)
# print(tf_test.shape)
# #------------------------------------------
# Out:
# 35347
# (11700, 35347)
# (2925, 35347)

# %%
# Tunning The Model
#-------------------------------------------------------------------------------
dnn=DNN(cv_train.shape[1],y_train.shape[1])
tunner=kt.Hyperband(hypermodel=dnn,objective="val_accuracy",max_epochs=4,factor=3,overwrite=True)
tunner.search_space_summary()
tunner.search(cv_train,y_train,epochs=20,validation_data=(cv_test,y_test),callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=3)])
best_hps = tunner.get_best_hyperparameters(num_trials=1)[0]
model = tunner.hypermodel.build(best_hps)
history=model.fit(cv_train, y_train, epochs=40,validation_data=(cv_test,y_test))
model.save(f"/content/drive/MyDrive/{areas[number]}/child_level_dnn.keras")
#-------------------------------------------------------------------------------



#Ploting
#------------------------------------------------------------------------------------------
epochs_number=len(history.history["accuracy"])+1
fig,axis=plt.subplots(2,1)

#Figure Accuracy
axis[0].plot(range(1,epochs_number),history.history["accuracy"],label="Train",color="green")
axis[0].plot(range(1,epochs_number),history.history["val_accuracy"],label="Validation",color="red")
axis[0].set_xlabel('Epochs')
axis[0].set_ylabel('Accuracy')
axis[0].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
axis[0].yaxis.set_ticks(np.arange(round(min(history.history["accuracy"])-0.05,1),round(max(history.history["accuracy"])+0.05,1),0.05))
#Figure Loss
axis[1].plot(range(1,epochs_number),history.history["loss"],label="Train",color="green")
axis[1].plot(range(1,epochs_number),history.history["val_loss"],label="Validation",color="red")
axis[1].set_xlabel('Epochs')
axis[1].set_ylabel('Loss')
axis[1].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axis[1].yaxis.set_ticks(np.arange(round(min(history.history["loss"])-0.1,1),round(max(history.history["loss"])+0.1,1),0.1))

axis[0].grid()
axis[1].grid()

axis[0].legend()
axis[1].legend()

fig.tight_layout()
fig.set_figheight(8)
fig.set_figwidth(6)



plt.show()
fig.savefig(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_DNN_plot.jpg")
#------------------------------------------------------------------------------------------


#Saving Model and Accuracy and Loss
#------------------------------------------------------------------------------------------
accuracy_text=' '.join([str(number)for number in history.history["accuracy"]])
loss_text=','.join([str(number)for number in history.history["loss"]])
val_accuracy_text=' '.join([str(number)for number in history.history["val_accuracy"]])
val_loss_text=' '.join([str(number)for number in history.history["val_loss"]])
with open(f"/content/drive/MyDrive/{areas[number]}/child_level_dnn_.txt","w") as f:
  f.write("Accuracy Train:"+accuracy_text+"\n")
  f.write("Loss Train:"+loss_text+"\n")
  f.write("Accuracy Test:"+val_accuracy_text+"\n")
  f.write("Loss Test:"+val_loss_text+"\n")
index=history.history["accuracy"].index(max(history.history["accuracy"]))
# 366/366 [==============================] - 4s 10ms/step - loss: 0.1594 - accuracy: 0.9614 - precision: 0.9647 - recall: 0.9589 - val_loss: 2.1901 - val_accuracy: 0.7156 - val_precision: 0.7547 - val_recall: 0.7005
# Epoch 12/40
# 366/366 [==============================] - 5s 15ms/step - loss: 0.1651 - accuracy: 0.9596 - precision: 0.9628 - recall: 0.9571 - val_loss: 2.3555 - val_accuracy: 0.7159 - val_precision: 0.7509 - val_recall: 0.7019
# Epoch 13/40
# 366/366 [==============================] - 5s 13ms/step - loss: 0.1377 - accuracy: 0.9669 - precision: 0.9703 - recall: 0.9649 - val_loss: 2.4337 - val_accuracy: 0.7169 - val_precision: 0.7527 - val_recall: 0.7056
# Epoch 14/40
# 366/366 [==============================] - 5s 13ms/step - loss: 0.1637 - accuracy: 0.9644 - precision: 0.9672 - recall: 0.9619 - val_loss: 2.5782 - val_accuracy: 0.7142 - val_precision: 0.7471 - val_recall: 0.7039
# Epoch 15/40
# 366/366 [==============================] - 4s 10ms/step - loss: 0.1714 - accuracy: 0.9627 - precision: 0.9658 - recall: 0.9605 - val_loss: 2.6128 - val_accuracy: 0.7159 - val_precision: 0.7447 - val_recall: 0.7060
# Epoch 16/40
# 366/366 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9643 - precision: 0.9667 - recall: 0.9631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-228097c5265e> in <cell line: 9>()
#       7 best_hps = tunner.get_best_hyperparameters(num_trials=1)[0]
#       8 model = tunner.hypermodel.build(best_hps)
# ----> 9 history=model.fit(cv_train, y_train, epochs=40,validation_data=(cv_test,y_test))
#      10 model.save(f"/content/drive/MyDrive/{areas[number]}/child_level_dnn.keras")
#      11 #-------------------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1854                             pss_evaluation_shards=self._pss_evaluation_shards,
#    1855                         )
# -> 1856                     val_logs = self.evaluate(
#    1857                         x=val_x,
#    1858                         y=val_y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2294                         ):
#    2295                             callbacks.on_test_batch_begin(step)
# -> 2296                             logs = test_function_runner.run_step(
#    2297                                 dataset_or_iterator,
#    2298                                 data_handler,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    4106
#    4107     def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4108         tmp_logs = self._function(dataset_or_iterator)
#    4109         if data_handler.should_sync:
#    4110             context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     875       # In this case we have not created variables on the first call. So we can
#     876       # run the first trace but we should fail if variables are created.
# --> 877       results = tracing_compilation.call_function(
#     878           args, kwds, self._variable_creation_config
#     879       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #XGBClassifier

# %%
# from sklearn.preprocessing import LabelEncoder
# label= LabelEncoder()
# labels=label.fit_transform(data["Domain"])

# %%
# pip install xgboost

# %%
# pip install scikit-optimize

# %%
# from sklearn.metrics import accuracy_score,precision_score,recall_score,make_scorer
# from xgboost import XGBClassifier
# from sklearn.pipeline import Pipeline
# from sklearn.model_selection import RandomizedSearchCV

# values=[]
# for key,documents_embedding in documents_embeddings.items():
#   #Random Search
#   #-----------------------------------------------------
#   xgboost=XGBClassifier(device="cuda")

#   params = {
#           "learning_rate":[0.0001],
#           "gamma": [0.2,0.4,0.6],
#           "colsample_bytree": [0.2,0.4,0.6],
#           "max_depth": [8],
#           }

#          # 'gamma': [0.2,0.4,0.6],
#         # 'colsample_bytree': [0,0.2,0.4,0.6],
#           # "max_depth": [6,7,8,9],
#   random_search = RandomizedSearchCV(xgboost, param_distributions=params,
#   scoring=["accuracy","precision_macro","recall_macro"],
#   refit="accuracy",verbose=3, random_state=1,cv=3,return_train_score=True)

#   random_search.fit(documents_embedding,labels)
#   #-----------------------------------------------------

#   #Saving Model and Accuracy and Loss
#   #------------------------------------------------------------------------------------------
#   cv_results=pd.DataFrame(random_search.cv_results_)
#   best_model_results=cv_results.loc[random_search.best_index_]


#   keys=["Classifier","Embedding","dim_size"]
#   row=["XGBClassifier",key,len(documents_embedding)]

#   for key,val in best_model_results.items():
#     if key=="params":
#       continue
#     if key.find("split")!=-1:
#       row.append(val)
#       keys.append(key)

#   values.append(row)
# pd.DataFrame(values,columns=keys).to_csv(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_XGBClassifier_OUTPU.csv")
#   #-----------------------------------------------------

# %% [markdown]
# #RNN MODEL

# %%
from sklearn.model_selection import KFold

for key,wv in words_embeddings_matrix.items():
  best_model=None
  best_accuracy=0
  overwrite=True
  #Using KFOLD
  kfold=KFold(n_splits=4,shuffle=True)
  fold=1
  for train,test in kfold.split(sequences_padded,data_multi_class):
    #KFOLD
    #------------------------------------------------------------------------------------------
    x_train=sequences_padded[train]
    x_test=sequences_padded[test]
    y_train=data_multi_class[train]
    y_test=data_multi_class[test]
    #------------------------------------------------------------------------------------------

    #RNN MODEL
    #-------------------------------------------------------------------------------
    rnn=RNN(wv,0,max_length=len(x_train[0]),nClasses=y_train.shape[1])
    model=rnn.build()
    history=model.fit(x_train, y_train, epochs=40,validation_data=(x_test,y_test),callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=3)])
    #-------------------------------------------------------------------------------


    #PLOTING
    #------------------------------------------------------------------------------------------
    epochs_number=len(history.history["accuracy"])+1
    fig,axis=plt.subplots(2,2)
    axis[0][0].plot(range(1,epochs_number),history.history["accuracy"],label="Accuracy Train")
    axis[0][1].plot(range(1,epochs_number),history.history["loss"],label="Lost Train")
    axis[1][0].plot(range(1,epochs_number),history.history["val_accuracy"],label="Accuracy Test")
    axis[1][1].plot(range(1,epochs_number),history.history["val_loss"],label="Loss Test")
    axis[0][0].grid()
    axis[0][1].grid()
    axis[1][0].grid()
    axis[1][1].grid()
    axis[0][0].legend()
    axis[0][1].legend()
    axis[1][0].legend()
    axis[1][1].legend()
    plt.show()
    fig.savefig(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_RNN_plot_{key}_{fold}.jpg")
    #------------------------------------------------------------------------------------------


    #Saving Model and Accuracy and Loss
    #------------------------------------------------------------------------------------------
    accuracy_text=' '.join([str(number)for number in history.history["accuracy"]])
    loss_text=','.join([str(number)for number in history.history["loss"]])
    val_accuracy_text=' '.join([str(number)for number in history.history["val_accuracy"]])
    val_loss_text=' '.join([str(number)for number in history.history["val_loss"]])
    with open(f"/content/drive/MyDrive/{areas[number]}/child_level_rnn_{key}_{fold}.txt","w") as f:
      f.write("Accuracy Train:"+accuracy_text+"\n")
      f.write("Loss Train:"+loss_text+"\n")
      f.write("Accuracy Test:"+val_accuracy_text+"\n")
      f.write("Loss Test:"+val_loss_text+"\n")
    index=history.history["accuracy"].index(max(history.history["accuracy"]))
    Excel_Output=pd.concat([Excel_Output,pd.DataFrame([{"Classifier":"RNN","Embedding":key,"Dimension_Size":wv.shape[1],"Train Accuracy":history.history["accuracy"][index],"Train Precision":history.history["precision"][index]," Train Recall":history.history["recall"][index],"Test Accuracy":history.history["val_accuracy"][index],"Test Precision":history.history["val_precision"][index]," Test Recall":history.history["val_recall"][index]}])])
    #------------------------------------------------------------------------------------------

    #Find The Best Model
    #-----------------------------------------------------------------------------------------
    if(history.history["val_accuracy"][index]>best_accuracy):
      best_accuracy=history.history["val_accuracy"][index]
      best_model=model
    #-----------------------------------------------------------------------------------------

    fold=fold+1

      #Saving The Model
  #---------------------------------------------------------------------------------------
  best_model.save(f"/content/drive/MyDrive/{areas[number]}/child_level_rnn_{key}.keras")
  #----------------------------------------------------------------------------------------
Excel_Output.to_csv(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_RNN_OUTPU.csv")
# Out:
# Epoch 1/40
# 168/168 [==============================] - 12s 29ms/step - loss: 2.6470 - accuracy: 0.1761 - precision: 0.8333 - recall: 9.3353e-04 - val_loss: 2.3850 - val_accuracy: 0.2699 - val_precision: 1.0000 - val_recall: 0.0017
# Epoch 2/40
# Epoch 15/40
# 168/168 [==============================] - 5s 30ms/step - loss: 0.9114 - accuracy: 0.7142 - precision: 0.8467 - recall: 0.5908 - val_loss: 1.1946 - val_accuracy: 0.6291 - val_precision: 0.7712 - val_recall: 0.5289
# Epoch 16/40
# 168/168 [==============================] - 6s 36ms/step - loss: 0.8539 - accuracy: 0.7359 - precision: 0.8440 - recall: 0.6220 - val_loss: 1.1720 - val_accuracy: 0.6381 - val_precision: 0.7654 - val_recall: 0.5373
# Epoch 17/40
# 168/168 [==============================] - 5s 30ms/step - loss: 0.8036 - accuracy: 0.7517 - precision: 0.8605 - recall: 0.6450 - val_loss: 1.1854 - val_accuracy: 0.6465 - val_precision: 0.7644 - val_recall: 0.5669
# Epoch 18/40
# 168/168 [==============================] - 5s 29ms/step - loss: 0.7922 - accuracy: 0.7594 - precision: 0.8626 - recall: 0.6657 - val_loss: 1.0659 - val_accuracy: 0.6773 - val_precision: 0.8130 - val_recall: 0.5821
# Epoch 19/40
# 168/168 [==============================] - 6s 36ms/step - loss: 0.7234 - accuracy: 0.7736 - precision: 0.8712 - recall: 0.6819 - val_loss: 1.0761 - val_accuracy: 0.6902 - val_precision: 0.7861 - val_recall: 0.6134
# Epoch 20/40
# 168/168 [==============================] - 5s 31ms/step - loss: 0.6878 - accuracy: 0.7868 - precision: 0.8714 - recall: 0.7047 - val_loss: 1.0793 - val_accuracy: 0.6908 - val_precision: 0.8000 - val_recall: 0.6073
# Epoch 21/40
# 168/168 [==============================] - 5s 30ms/step - loss: 0.6474 - accuracy: 0.7960 - precision: 0.8773 - recall: 0.7181 - val_loss: 1.0862 - val_accuracy: 0.6863 - val_precision: 0.7856 - val_recall: 0.6179

# %% [markdown]
# #DNN DOC

# %%
child_document_embeddings={}

for key,document_embeding in documents_embeddings.items():
  child_document_embeding=[]
  for index in data["index"]:
    child_document_embeding.append(document_embeding.docvecs.vectors[index])
  child_document_embeddings[key]=np.array(child_document_embeding)
child_document_embeddings['doc2vec300'].shape
# Out:
# <ipython-input-30-6b63398ad1f3>:6: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   child_document_embeding.append(document_embeding.docvecs.vectors[index])
# (3297, 300)

# %%
import math
for key,documents_embedding in child_document_embeddings.items():
  best_model=None
  best_accuracy=0
  overwrite=True
  #Using KFOLD
  kfold=KFold(n_splits=4,shuffle=True)
  fold=1
  for train,test in kfold.split(documents_embedding,data_multi_class):
    #KFOLD
    #------------------------------------------------------------------------------------------
    x_train=documents_embedding[train]
    x_test=documents_embedding[test]
    y_train=data_multi_class[train]
    y_test=data_multi_class[test]
    #------------------------------------------------------------------------------------------


    #MODEL
    #------------------------------------------------------------------------------------------
    dnn=DNN(x_train.shape[1],y_train.shape[1])
    tunner=kt.Hyperband(hypermodel=dnn,objective="val_accuracy",max_epochs=4,factor=3,overwrite=overwrite)
    tunner.search_space_summary()
    tunner.search(x_train,y_train,batch_size=128,epochs=20,validation_data=(x_test,y_test),callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=3)])
    best_hps = tunner.get_best_hyperparameters(num_trials=1)[0]
    model = tunner.hypermodel.build(best_hps)
    history=model.fit(x_train, y_train,batch_size=256,epochs=25,validation_data=(x_test,y_test))
    overwrite=False
    #------------------------------------------------------------------------------------------


    #PLOTING
    #------------------------------------------------------------------------------------------
    epochs_number=len(history.history["accuracy"])+1
    fig,axis=plt.subplots(2,1)

    #Figure Accuracy
    axis[0].plot(range(1,epochs_number),history.history["accuracy"],label="Train",color="green")
    axis[0].plot(range(1,epochs_number),history.history["val_accuracy"],label="Validation",color="red")
    axis[0].set_xlabel('Epochs')
    axis[0].set_ylabel('Accuracy')
    axis[0].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    axis[0].yaxis.set_ticks(np.arange(round(min(history.history["accuracy"])-0.05,1),round(max(history.history["accuracy"])+0.05,1),0.05))
    #Figure Loss
    axis[1].plot(range(1,epochs_number),history.history["loss"],label="Train",color="green")
    axis[1].plot(range(1,epochs_number),history.history["val_loss"],label="Validation",color="red")
    axis[1].set_xlabel('Epochs')
    axis[1].set_ylabel('Loss')
    axis[1].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
    axis[1].yaxis.set_ticks(np.arange(round(min(history.history["loss"])-0.1,1),round(max(history.history["loss"])+0.1,1),0.1))

    axis[0].grid()
    axis[1].grid()

    axis[0].legend()
    axis[1].legend()

    fig.tight_layout()
    fig.set_figheight(8)
    fig.set_figwidth(6)



    plt.show()
    fig.savefig(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_DNN_DOC_plot_{key}_{fold}.jpg")
    #------------------------------------------------------------------------------------------


    #Saving Model and Accuracy and Loss
    #------------------------------------------------------------------------------------------
    accuracy_text=' '.join([str(number)for number in history.history["accuracy"]])
    loss_text=','.join([str(number)for number in history.history["loss"]])
    val_accuracy_text=' '.join([str(number)for number in history.history["val_accuracy"]])
    val_loss_text=' '.join([str(number)for number in history.history["val_loss"]])
    with open(f"/content/drive/MyDrive/{areas[number]}/child_level_dnn_Doc_{key}_{fold}.txt","w") as f:
      f.write("Accuracy Train:"+accuracy_text+"\n")
      f.write("Loss Train:"+loss_text+"\n")
      f.write("Accuracy Test:"+val_accuracy_text+"\n")
      f.write("Loss Test:"+val_loss_text+"\n")
    index=history.history["accuracy"].index(max(history.history["accuracy"]))
    Excel_Output=pd.concat([Excel_Output,pd.DataFrame([{"Classifier":"DNN","Embedding":key,"Dimension_Size":x_train.shape[1],"Train Accuracy":history.history["accuracy"][index],"Train Precision":history.history["precision"][index]," Train Recall":history.history["recall"][index],"Test Accuracy":history.history["val_accuracy"][index],"Test Precision":history.history["val_precision"][index]," Test Recall":history.history["val_recall"][index]}])])
    #------------------------------------------------------------------------------------------

    fold=fold+1
     #Find The Best Model
    #-----------------------------------------------------------------------------------------
    if(history.history["val_accuracy"][index]>best_accuracy):
      best_accuracy=history.history["val_accuracy"][index]
      best_model=model
    #-----------------------------------------------------------------------------------------

  #Saving The Mode
  #---------------------------------------------------------------------------------------
  best_model.save(f"/content/drive/MyDrive/{areas[number]}/child_level_dnn_doc_{key}.keras")
# Epoch 21/25
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6789 - accuracy: 0.7825 - precision: 0.8533 - recall: 0.6866 - val_loss: 1.0342 - val_accuracy: 0.6857 - val_precision: 0.7395 - val_recall: 0.5995
# Epoch 22/25
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6736 - accuracy: 0.7776 - precision: 0.8539 - recall: 0.6899 - val_loss: 1.0392 - val_accuracy: 0.6833 - val_precision: 0.7363 - val_recall: 0.6032
# Epoch 23/25
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6624 - accuracy: 0.7804 - precision: 0.8485 - recall: 0.7000 - val_loss: 1.0470 - val_accuracy: 0.6893 - val_precision: 0.7292 - val_recall: 0.5947
# Epoch 24/25
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6436 - accuracy: 0.7845 - precision: 0.8508 - recall: 0.6919 - val_loss: 1.0534 - val_accuracy: 0.6833 - val_precision: 0.7429 - val_recall: 0.6068
# Epoch 25/25
# 10/10 [==============================] - 0s 12ms/step - loss: 0.6518 - accuracy: 0.7788 - precision: 0.8492 - recall: 0.7012 - val_loss: 1.0650 - val_accuracy: 0.6735 - val_precision: 0.7185 - val_recall: 0.5947

# %% [markdown]
# #RNN DOC

# %%
import numpy as np

test=[]
for index in data['index']:
  numbers=[]
  numbers.append(index)
  test.append(numbers)
sequence=np.array(test)
sequence.shape
# Out:
# (6514, 1)

# %%
class RNN_DOC():
  def __init__(self,dc,complexity,max_length,nClasses):
    self.dc=dc
    self.complexity=complexity
    self.max_length=max_length
    self.nClasses=nClasses

  def build(self):
    model = Sequential()
    model.add(Embedding(input_dim=(self.dc.shape[0]),
                        output_dim=(self.dc.shape[1]),
                        weights=[self.dc],
                        input_length=self.max_length,
                        trainable=False))

    model.add(GRU(100))
    model.add(Dense(self.nClasses, activation='softmax'))
    model.compile(optimizer=RMSprop(learning_rate=0.001),loss=["categorical_crossentropy"],metrics=["accuracy",Precision(name="precision"),Recall(name="recall")])
    return model

# %%
for key,documents_embedding in documents_embeddings.items():
  best_model=None
  best_accuracy=0
  overwrite=True
  #Using KFOLD
  kfold=KFold(n_splits=4,shuffle=True)
  fold=1
  for train,test in kfold.split(sequence,data_multi_class):
    #KFOLD
    #------------------------------------------------------------------------------------------
    x_train=sequence[train]
    x_test=sequence[test]
    y_train=data_multi_class[train]
    y_test=data_multi_class[test]
    #------------------------------------------------------------------------------------------


    #RNN MODEL
    #-------------------------------------------------------------------------------
    rnn=RNN(documents_embedding,0,max_length=len(x_train[0]),nClasses=y_train.shape[1])
    model=rnn.build()
    history=model.fit(x_train, y_train, batch_size=64,epochs=40,validation_data=(x_test,y_test),callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=3)])
    #-------------------------------------------------------------------------------


    #PLOTING
    #------------------------------------------------------------------------------------------
    epochs_number=len(history.history["accuracy"])+1
    fig,axis=plt.subplots(2,2)
    axis[0][0].plot(range(1,epochs_number),history.history["accuracy"],label="Accuracy Train")
    axis[0][1].plot(range(1,epochs_number),history.history["loss"],label="Lost Train")
    axis[1][0].plot(range(1,epochs_number),history.history["val_accuracy"],label="Accuracy Test")
    axis[1][1].plot(range(1,epochs_number),history.history["val_loss"],label="Loss Test")
    axis[0][0].grid()
    axis[0][1].grid()
    axis[1][0].grid()
    axis[1][1].grid()
    axis[0][0].legend()
    axis[0][1].legend()
    axis[1][0].legend()
    axis[1][1].legend()
    plt.show()
    fig.savefig(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_RNN_DOC_plot_{key}_{fold}.jpg")
    #------------------------------------------------------------------------------------------


    #Saving Model and Accuracy and Loss
    #------------------------------------------------------------------------------------------
    accuracy_text=' '.join([str(number)for number in history.history["accuracy"]])
    loss_text=','.join([str(number)for number in history.history["loss"]])
    val_accuracy_text=' '.join([str(number)for number in history.history["val_accuracy"]])
    val_loss_text=' '.join([str(number)for number in history.history["val_loss"]])
    with open(f"/content/drive/MyDrive/{areas[number]}/child_level_rnn_Doc_{key}_{fold}.txt","w") as f:
      f.write("Accuracy Train:"+accuracy_text+"\n")
      f.write("Loss Train:"+loss_text+"\n")
      f.write("Accuracy Test:"+val_accuracy_text+"\n")
      f.write("Loss Test:"+val_loss_text+"\n")
    index=history.history["accuracy"].index(max(history.history["accuracy"]))
    Excel_Output=pd.concat([Excel_Output,pd.DataFrame([{"Classifier":"RNN","Embedding":key,"Dimension_Size":x_train.shape[1],"Train Accuracy":history.history["accuracy"][index],"Train Precision":history.history["precision"][index]," Train Recall":history.history["recall"][index],"Test Accuracy":history.history["val_accuracy"][index],"Test Precision":history.history["val_precision"][index]," Test Recall":history.history["val_recall"][index]}])])
    #------------------------------------------------------------------------------------------

    fold=fold+1
     #Find The Best Model
    #-----------------------------------------------------------------------------------------
    if(history.history["val_accuracy"][index]>best_accuracy):
      best_accuracy=history.history["val_accuracy"][index]
      best_model=model
    #-----------------------------------------------------------------------------------------

  #Saving The Mode
  #---------------------------------------------------------------------------------------
  best_model.save(f"/content/drive/MyDrive/{areas[number]}/child_level_rnn_doc_{key}.keras")
  #----------------------------------------------------------------------------------------

Excel_Output.to_csv(f"/content/drive/MyDrive/{areas[number]}/{areas[number]}_RNN_DOC_OUTPU.csv")
# Out:
# Epoch 1/40
# 77/77 [==============================] - 5s 21ms/step - loss: 2.6561 - accuracy: 0.1799 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.5048 - val_accuracy: 0.2302 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/40
# 77/77 [==============================] - 1s 9ms/step - loss: 2.3064 - accuracy: 0.3230 - precision: 0.9040 - recall: 0.0231 - val_loss: 2.2017 - val_accuracy: 0.3499 - val_precision: 0.8194 - val_recall: 0.0362
# Epoch 3/40
# 77/77 [==============================] - 1s 10ms/step - loss: 2.0497 - accuracy: 0.3906 - precision: 0.9169 - recall: 0.0790 - val_loss: 2.0096 - val_accuracy: 0.3812 - val_precision: 0.8800 - val_recall: 0.1080
# Epoch 4/40
# 77/77 [==============================] - 1s 7ms/step - loss: 1.8840 - accuracy: 0.4332 - precision: 0.8854 - recall: 0.1218 - val_loss: 1.8645 - val_accuracy: 0.4107 - val_precision: 0.8036 - val_recall: 0.1381
# Epoch 5/40
# 77/77 [==============================] - 1s 7ms/step - loss: 1